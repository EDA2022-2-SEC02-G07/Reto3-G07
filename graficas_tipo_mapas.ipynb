# %%
import numpy as np
import matplotlib.pyplot as plt

pct = np.array([0.5, 5, 10, 20, 30, 50, 80, 100])

t_req1 = np.array([14.05, 18.61, 24.38, 42.72, 27.93, 26.58, 25.35, 32.26])
z_t_req1 = np.polyfit(pct, t_req1, 2)
p_t_req1 = np.poly1d(z_t_req1)

t_req2 = np.array([5.97, 3.82, 4.62, 14.46, 5.12, 1.52, 0.99, 1.62])
z_t_req2 = np.polyfit(pct, t_req2, 2)
p_t_req2 = np.poly1d(z_t_req2)

t_req3 = np.array([45.99, 52.11, 75.32, 117.30, 200.69, 276.29, 445.17, 741.85])
z_t_req3 = np.polyfit(pct, t_req3, 2)
p_t_req3 = np.poly1d(z_t_req3)

t_req4 = np.array([7.68, 27.39, 49.41, 142.85, 166.34, 311.38, 379.19, 567.49])
z_t_req4 = np.polyfit(pct, t_req4, 2)
p_t_req4 = np.poly1d(z_t_req4)

t_req5 = np.array([24.17, 27.61, 30.20, 35.79, 41.92, 46.39, 38.45, 46.29])
z_t_req5 = np.polyfit(pct, t_req5, 2)
p_t_req5 = np.poly1d(z_t_req5)

t_req6 = np.array([6.78, 10.95])
z_t_req6 = np.polyfit(pct, t_req6, 2)
p_t_req6 = np.poly1d(z_t_req6)

t_req7 = np.array([35.77, 84.98, 123.59, 209.38, 322.37, 439.60, 763.78, 990.02])
z_t_req7 = np.polyfit(pct, t_req7, 2)
p_t_req7 = np.poly1d(z_t_req7)

t_req8 = np.array([132.98, 217.05, 325.89, 692.47, 800.57, 1144.62, 1675.62, 1935.81])
z_t_req8 = np.polyfit(pct, t_req8, 2)
p_t_req8 = np.poly1d(z_t_req8)

plt.figure(figsize=[16, 8])

plt.subplot(2, 4, 1)
plt.scatter(pct, t_req1,  c='b')
plt.plot(pct, p_t_req1(pct),'--b')
plt.grid(1)
plt.xlabel('% de la muestra')
plt.ylabel('Tiempo de Ejecución Real [ms]')
plt.title('Reqerimiento 1')
plt.tight_layout()

plt.subplot(2, 4, 2)
plt.scatter(pct, t_req2,  c='r')
plt.plot(pct, p_t_req2(pct),'--r')
plt.grid(1)
plt.xlabel('% de la muestra')
plt.ylabel('Tiempo de Ejecución Real [ms]')
plt.title('Reqerimiento 2')
plt.tight_layout()

plt.subplot(2, 4, 3)
plt.scatter(pct, t_req3,  c='g')
plt.plot(pct, p_t_req3(pct),'--g')
plt.grid(1)
plt.xlabel('% de la muestra')
plt.ylabel('Tiempo de Ejecución Real [ms]')
plt.title('Reqerimiento 3')
plt.tight_layout()

plt.subplot(2, 4, 4)
plt.scatter(pct, t_req4,  c='y')
plt.plot(pct, p_t_req4(pct),'--y')
plt.grid(1)
plt.xlabel('% de la muestra')
plt.ylabel('Tiempo de Ejecución Real [ms]')
plt.title('Reqerimiento 4')
plt.tight_layout()

plt.subplot(2, 4, 5)
plt.scatter(pct, t_req5,  c='orange')
plt.plot(pct, p_t_req5(pct),'--', c='orange')
plt.grid(1)
plt.xlabel('% de la muestra')
plt.ylabel('Tiempo de Ejecución Real [ms]')
plt.title('Reqerimiento 5')
plt.tight_layout()

plt.subplot(2, 4, 6)
plt.scatter(pct, t_req6,  c='blueviolet')
plt.plot(pct, p_t_req6(pct),'--', c='blueviolet')
plt.grid(1)
plt.xlabel('% de la muestra')
plt.ylabel('Tiempo de Ejecución Real [ms]')
plt.title('Reqerimiento 6')
plt.tight_layout()

plt.subplot(2, 4, 7)
plt.scatter(pct, t_req7,  c='deeppink')
plt.plot(pct, p_t_req7(pct),'--', c='deeppink')
plt.grid(1)
plt.xlabel('% de la muestra')
plt.ylabel('Tiempo de Ejecución Real [ms]')
plt.title('Reqerimiento 7')
plt.tight_layout()

plt.subplot(2, 4, 8)
plt.scatter(pct, t_req8,  c='darkcyan')
plt.plot(pct, p_t_req8(pct),'--', c = 'darkcyan')
plt.grid(1)
plt.xlabel('% de la muestra')
plt.ylabel('Tiempo de Ejecución Real [ms]')
plt.title('Reqerimiento 8')
plt.tight_layout()

plt.tight_layout()
plt.show()
